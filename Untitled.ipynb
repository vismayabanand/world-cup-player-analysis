# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("Batsman_Data.csv")   # reading all the rows and columns
#Since a player did not bat in a particular match I'm using df.replace()

df=df.replace("DNB",-1)
df=df.replace("TDNB",-1)
df=df.replace("-",0)
#TO replace v India and so on to India 


a2=list(set(df['Opposition']))
a3= ["India","Australia","England","Bangladesh","West Indies","Afghanistan","Pakistan","South Africa","New Zealand","Sri Lanka"]
a4=[]
for i in a2:
    a4.append(i[2:])
a5=list(set(a4)-set(a3))

a6=[]
for j in a5:
    a6.append("v "+j)




for i in range(0,len(a6),1):
        
        df=df.replace(a6[i],np.nan)
    
df=df.dropna()

for i in df:
    df.loc[df['Opposition']=='v India', 'Opposition']='India'
    df.loc[df['Opposition']=='v Australia','Opposition']='Australia'
    df.loc[df['Opposition']=='v Sri Lanka','Opposition']='Sri Lanka'
    df.loc[df['Opposition']=='v New Zealand','Opposition']='New Zealand'
    df.loc[df['Opposition']=='v South Africa','Opposition']='South Africa'
    df.loc[df['Opposition']=='v Afghanistan','Opposition']='Afghanistan'
    df.loc[df['Opposition']=='v Pakistan','Opposition']='Pakistan'
    df.loc[df['Opposition']=='v West Indies','Opposition']='West Indies'
    df.loc[df['Opposition']=='v England','Opposition']='England'
    df.loc[df['Opposition']=='v Bangladesh','Opposition']='Bangladesh'


df=df.drop(['Player_ID','Match_ID','Start Date'],axis=1)
df=df.drop(df.columns[0],axis=1)

df
# Out:
#       Bat1 Runs  BF      SR 4s 6s   Opposition           Ground  \
# 0       16   16  28   57.14  0  0    Sri Lanka        Melbourne
# 1        4    4  15   26.66  0  0    Sri Lanka         Adelaide
# 2       10   10   6  166.66  1  0  West Indies            Perth
# 3       11   11  22      50  2  0  West Indies            Perth
# 4       38   38  41   92.68  5  0  West Indies         Canberra
# ...    ...  ...  ..     ... .. ..          ...              ...
# 11144   -1    0   0       0  0  0  New Zealand  Mount Maunganui
# 11145   -1    0   0       0  0  0  New Zealand  Mount Maunganui
# 11146  18*   18  37   48.64  3  0  New Zealand         Hamilton
# 11147   0*    0   1       0  0  0  New Zealand       Wellington
# 11148    0    0   1       0  0  0    Australia           Mohali
#
#                 Batsman
# 0          Aaron Finch
# 1          Aaron Finch
# 2          Aaron Finch
# 3          Aaron Finch
# 4          Aaron Finch
# ...                 ...
# 11144  Yuzvendra Chahal
# 11145  Yuzvendra Chahal
# 11146  Yuzvendra Chahal
# 11147  Yuzvendra Chahal
# 11148  Yuzvendra Chahal
#
# [9364 rows x 9 columns]

# %%
p1=list(set(df['Runs']))
for i in range(0,len(p1),1):
    df=df.replace(p1[i],int(p1[i]))
p2=list(set(df['Batsman']))


g=df.groupby(['Batsman','Opposition'])
g1=[]
g2=[]
for i,j in g:
    g1.append(list(i))
    g2.append(str(j.Runs.mean()))

# %%
df1=pd.read_csv("Bowler_data.csv")
   #dropping first column 
#Replacing average to 0 when the bowler doesn't take any wickets in that match
df1=df1.replace("-",0)


        
a2=list(set(df1['Opposition']))
a3= ["India","Australia","England","Bangladesh","West Indies","Afghanistan","Pakistan","South Africa","New Zealand","Sri Lanka"]
a4=[]
for i in a2:
    a4.append(i[2:])
a5=list(set(a4)-set(a3))
a6=[]
for j in a5:
    a6.append("v "+j)




for i in range(0,len(a6),1):
        
        df1=df1.replace(a6[i],np.nan)
    
df1=df1.dropna()
#df1=df1.drop(df.columns[0],axis=1)
for i in df1:
    df1.loc[df1['Opposition']=='v India', 'Opposition']='India'
    df1.loc[df1['Opposition']=='v Australia','Opposition']='Australia'
    df1.loc[df1['Opposition']=='v Sri Lanka','Opposition']='Sri Lanka'
    df1.loc[df1['Opposition']=='v New Zealand','Opposition']='New Zealand'
    df1.loc[df1['Opposition']=='v South Africa','Opposition']='South Africa'
    df1.loc[df1['Opposition']=='v Afghanistan','Opposition']='Afghanistan'
    df1.loc[df1['Opposition']=='v Pakistan','Opposition']='Pakistan'
    df1.loc[df1['Opposition']=='v West Indies','Opposition']='West Indies'
    df1.loc[df1['Opposition']=='v England','Opposition']='England'
    df1.loc[df1['Opposition']=='v Bangladesh','Opposition']='Bangladesh'

df1=df1.drop(['Player_ID','Match_ID','Start Date','SR'],axis=1)
df1=df1.drop(df1.columns[0],axis=1)

# %%
df1
# Out:
#       Overs Mdns Runs Wkts  Econ    Ave   Opposition           Ground  \
# 0         0    0    0    0     0      0    Sri Lanka        Melbourne
# 1         0    0    0    0     0      0    Sri Lanka         Adelaide
# 2         0    0    0    0     0      0  West Indies            Perth
# 3         0    0    0    0     0      0  West Indies            Perth
# 4         0    0    0    0     0      0  West Indies         Canberra
# ...     ...  ...  ...  ...   ...    ...          ...              ...
# 11113   9.2    0   52    2  5.57     26  New Zealand  Mount Maunganui
# 11114     9    0   51    2  5.66   25.5  New Zealand  Mount Maunganui
# 11115   2.4    0   32    0    12      0  New Zealand         Hamilton
# 11116    10    0   41    3   4.1  13.66  New Zealand       Wellington
# 11117    10    0   80    1     8     80    Australia           Mohali
#
#                  Bowler
# 0          Aaron Finch
# 1          Aaron Finch
# 2          Aaron Finch
# 3          Aaron Finch
# 4          Aaron Finch
# ...                 ...
# 11113  Yuzvendra Chahal
# 11114  Yuzvendra Chahal
# 11115  Yuzvendra Chahal
# 11116  Yuzvendra Chahal
# 11117  Yuzvendra Chahal
#
# [9344 rows x 9 columns]

# %%
p1=list(set(df1['Wkts']))
for i in range(0,len(p1),1):
    df1=df1.replace(p1[i],int(p1[i]))
p2=list(set(df1['Bowler']))


g=df1.groupby(['Bowler','Opposition'])
a=[]
b=[]
for i,j in g:
    a.append(list(i))
    b.append(j.Wkts.mean())
f=[]
for i in a:
    f.append(i[0])

# %%
df2=pd.read_csv("Ground_Averages.csv")
df2=df2.drop(['Span','NR'],axis=1)

# %%
df2
# Out:
#                                                 Ground  Mat  Won  Tied  Runs  \
# 0                        Eden Gardens, Kolkata - India    4    4     0  2161
# 1                      Feroz Shah Kotla, Delhi - India    4    4     0  1789
# 2                 Melbourne Cricket Ground - Australia   15   15     0  7656
# 3    Saurashtra Cricket Association Stadium, Rajkot...    2    2     0  1163
# 4                            Adelaide Oval - Australia   10   10     0  4863
# ..                                                 ...  ...  ...   ...   ...
# 101  Greenfield International Stadium, Thiruvananth...    1    1     0   209
# 102  Sylhet International Cricket Stadium - Bangladesh    1    1     0   400
# 103  Rajiv Gandhi International Cricket Stadium, De...    5    4     0  1864
# 104       Wanderers Cricket Ground, Windhoek - Namibia    1    1     0   307
# 105                    Affies Park, Windhoek - Namibia    1    1     0   329
#
#      Wkts  Balls    Ave   RPO
# 0      72   2297  30.01  5.64
# 1      75   2331  23.85  4.60
# 2     217   8482  35.28  5.41
# 3      26   1200  44.73  5.81
# 4     157   5645  30.97  5.16
# ..    ...    ...    ...   ...
# 101    11    280  19.00  4.47
# 102    11    531  36.36  4.51
# 103    67   2524  27.82  4.43
# 104    17    474  18.05  3.88
# 105    15    460  21.93  4.29
#
# [106 rows x 9 columns]

# %%
df3=pd.read_csv("ODI_Match_Totals.csv")


df3.head()

df3=df3.drop([df3.columns[0],df3.columns[9],df3.columns[10],df3.columns[12]],axis='columns')#remove columns

df3.head()

columns=list(df3)

for i in columns: #replace respective values by desired value
    df3.loc[df3['Result']=='won', 'Result']=1
    df3.loc[df3['Result']=='lost','Result']=0
    df3.loc[df3['Result']=='n/r','Result']=-1
    df3.loc[df3['Result']=='aban','Result']=-1
    df3.loc[df3['Result']=='tied','Result']=-1


df3=df3[~df3.Opposition.str.contains("v Ireland")] #remove rows with these countries
df3=df3[~df3.Opposition.str.contains("v U.S.A.")]
df3=df3[~df3.Opposition.str.contains("v U.A.E")]
df3=df3[~df3.Opposition.str.contains("v Netherlands")]
df3=df3[~df3.Opposition.str.contains("v Kenya")]
df3=df3[~df3.Opposition.str.contains("v Zimbabwe")]
df3=df3[~df3.Opposition.str.contains("v P.N.G")]
df3=df3[~df3.Opposition.str.contains("v Hong Kong")]

for i in columns:  #correct name 
    df3.loc[df3['Country']=='Newzealad', 'Country']='New Zealand'


for i in columns:  #removing 'v' 
    df3.loc[df3['Opposition']=='v Australia', 'Opposition']='Australia'
    df3.loc[df3['Opposition']=='v New Zealand', 'Opposition']='New Zealand'
    df3.loc[df3['Opposition']=='v England', 'Opposition']='England'
    df3.loc[df3['Opposition']=='v Sri Lanka', 'Opposition']='Sri Lanka'
    df3.loc[df3['Opposition']=='v South Africa', 'Opposition']='South Africa'
    df3.loc[df3['Opposition']=='v West Indies', 'Opposition']='West Indies'
    df3.loc[df3['Opposition']=='v Pakistan', 'Opposition']='Pakistan'
    df3.loc[df3['Opposition']=='v Afghanistan', 'Opposition']='Afghanistan'
    df3.loc[df3['Opposition']=='v Bangladesh', 'Opposition']='Bangladesh'
    df3.loc[df3['Opposition']=='v India', 'Opposition']='India'


df3['Target']=df3['Target'].fillna("YTB") #replace nan values by YTB in 'Target' column

df3.head()

for i in columns: #replacing the RPO in unheld matches by 0
    df3.loc[df3['RPO']=='-', 'RPO']=0
    df3.loc[df3['Result']=='-','Result']=-1
# Out:
# C:\Users\vishw\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
df3
# Out:
#       Score  Overs   RPO Target  Inns  Result   Opposition             Ground  \
# 0       250   48.3  5.15    YTB     1       1        India            Kolkata
# 1       165   48.0  3.43    251     2       0     Pakistan            Kolkata
# 2       157   48.5  3.21    168     2       0        India              Delhi
# 3       167   43.4  3.82    YTB     1       1     Pakistan              Delhi
# 4       198   40.0  4.95    306     2       0    Australia          Melbourne
# ...     ...    ...   ...    ...   ...     ...          ...                ...
# 1290  213/5   22.5  9.32    210     2       1  West Indies  Dublin (Malahide)
# 1291  340/7   50.0  6.80    YTB     1       0      England         Nottingham
# 1292  341/7   49.3  6.88    341     2       1     Pakistan         Nottingham
# 1294  193/6   31.5  6.06    352     2      -1      England              Leeds
# 1295  351/9   50.0  7.02    YTB     1      -1     Pakistan              Leeds
#
#          Country
# 0       Pakistan
# 1          India
# 2       Pakistan
# 3          India
# 4       SriLanka
# ...          ...
# 1290  Bangladesh
# 1291    Pakistan
# 1292     England
# 1294    Pakistan
# 1295     England
#
# [1127 rows x 9 columns]

# %%
df
# Out:
#       Bat1  Runs  BF      SR  4s  6s   Opposition           Ground  \
# 0       16    16  28   57.14   0   0    Sri Lanka        Melbourne
# 1        4     4  15   26.66   0   0    Sri Lanka         Adelaide
# 2       10    10   6  166.66   1   0  West Indies            Perth
# 3       11    11  22      50   2   0  West Indies            Perth
# 4       38    38  41   92.68   5   0  West Indies         Canberra
# ...    ...   ...  ..     ...  ..  ..          ...              ...
# 11144   -1     0   0       0   0   0  New Zealand  Mount Maunganui
# 11145   -1     0   0       0   0   0  New Zealand  Mount Maunganui
# 11146  18*    18  37   48.64   3   0  New Zealand         Hamilton
# 11147   0*     0   1       0   0   0  New Zealand       Wellington
# 11148    0     0   1       0   0   0    Australia           Mohali
#
#                 Batsman
# 0          Aaron Finch
# 1          Aaron Finch
# 2          Aaron Finch
# 3          Aaron Finch
# 4          Aaron Finch
# ...                 ...
# 11144  Yuzvendra Chahal
# 11145  Yuzvendra Chahal
# 11146  Yuzvendra Chahal
# 11147  Yuzvendra Chahal
# 11148  Yuzvendra Chahal
#
# [9364 rows x 9 columns]

# %%
p1=list(set(df['BF']))
for i in range(0,len(p1),1):
    df=df.replace(p1[i],int(p1[i]))
    
p1=list(set(df['4s']))
for i in range(0,len(p1),1):
    df=df.replace(p1[i],int(p1[i]))
    
p1=list(set(df['6s']))
for i in range(0,len(p1),1):
    df=df.replace(p1[i],int(p1[i]))
    
    
p=list(set(df['SR']))
#p1=[float(x) for x in p]
for i in p:
    df=df.replace(i,float(i))


gbat=df.groupby(['Batsman']).transform(lambda x: (x - x.mean()) / x.std())

# %%
df1
# Out:
#       Overs  Mdns Runs  Wkts  Econ    Ave   Opposition           Ground  \
# 0         0     0    0     0     0      0    Sri Lanka        Melbourne
# 1         0     0    0     0     0      0    Sri Lanka         Adelaide
# 2         0     0    0     0     0      0  West Indies            Perth
# 3         0     0    0     0     0      0  West Indies            Perth
# 4         0     0    0     0     0      0  West Indies         Canberra
# ...     ...   ...  ...   ...   ...    ...          ...              ...
# 11113   9.2     0   52     2  5.57     26  New Zealand  Mount Maunganui
# 11114     9     0   51     2  5.66   25.5  New Zealand  Mount Maunganui
# 11115   2.4     0   32     0    12      0  New Zealand         Hamilton
# 11116    10     0   41     3   4.1  13.66  New Zealand       Wellington
# 11117    10     0   80     1     8     80    Australia           Mohali
#
#                  Bowler
# 0          Aaron Finch
# 1          Aaron Finch
# 2          Aaron Finch
# 3          Aaron Finch
# 4          Aaron Finch
# ...                 ...
# 11113  Yuzvendra Chahal
# 11114  Yuzvendra Chahal
# 11115  Yuzvendra Chahal
# 11116  Yuzvendra Chahal
# 11117  Yuzvendra Chahal
#
# [9344 rows x 9 columns]

# %%
p1=list(set(df1['Wkts']))
for i in range(0,len(p1),1):
    df1=df1.replace(p1[i],int(p1[i]))
    
p1=list(set(df1['Runs']))
for i in range(0,len(p1),1):
    df1=df1.replace(p1[i],int(p1[i]))
    
p1=list(set(df1['Ave']))
for i in range(0,len(p1),1):
    df1=df1.replace(p1[i],float(p1[i]))
    
    
p=list(set(df1['Econ']))
#p1=[float(x) for x in p]
for i in p:
    df1=df1.replace(i,float(i))



gbowl=df1.groupby(['Bowler']).transform(lambda x: (x - x.mean()) / x.std())

# %%
wk=[]
econ=[]
ave=[]
f5=list(df1['Opposition'])
f1=list(df1['Bowler'])
f2=list(df1['Wkts'])
f3=list(df1['Econ'])
f4=list(df1['Ave'])
for j in range(0,len(f1),1):
    if(f1[j] =='Adam Zampa'):
        wk.append(int(f2[j]))
        econ.append(float(f3[j]))
        ave.append(float(f4[j]))

# %%
df
# Out:
#       Bat1  Runs  BF      SR  4s  6s   Opposition           Ground  \
# 0       16    16  28   57.14   0   0    Sri Lanka        Melbourne
# 1        4     4  15   26.66   0   0    Sri Lanka         Adelaide
# 2       10    10   6  166.66   1   0  West Indies            Perth
# 3       11    11  22   50.00   2   0  West Indies            Perth
# 4       38    38  41   92.68   5   0  West Indies         Canberra
# ...    ...   ...  ..     ...  ..  ..          ...              ...
# 11144   -1     0   0    0.00   0   0  New Zealand  Mount Maunganui
# 11145   -1     0   0    0.00   0   0  New Zealand  Mount Maunganui
# 11146  18*    18  37   48.64   3   0  New Zealand         Hamilton
# 11147   0*     0   1    0.00   0   0  New Zealand       Wellington
# 11148    0     0   1    0.00   0   0    Australia           Mohali
#
#                 Batsman
# 0          Aaron Finch
# 1          Aaron Finch
# 2          Aaron Finch
# 3          Aaron Finch
# 4          Aaron Finch
# ...                 ...
# 11144  Yuzvendra Chahal
# 11145  Yuzvendra Chahal
# 11146  Yuzvendra Chahal
# 11147  Yuzvendra Chahal
# 11148  Yuzvendra Chahal
#
# [9364 rows x 9 columns]

# %%
df.to_csv("Batsmannorm.csv")

# %%
df1.to_csv("Bowlernorm.csv")

# %%
print(gbat)
# Out:
#            Runs        BF        SR        4s        6s
# 0     -0.530510 -0.337359 -0.344079 -1.020189 -0.605258
# 1     -0.844923 -0.656925 -1.012365 -1.020189 -0.605258
# 2     -0.687717 -0.878163  2.057192 -0.738295 -0.605258
# 3     -0.661515 -0.484851 -0.500626 -0.456400 -0.605258
# 4      0.045914 -0.017793  0.435150  0.389283 -0.605258
# ...         ...       ...       ...       ...       ...
# 11144 -0.260851 -0.280187 -0.324964 -0.230961       NaN
# 11145 -0.260851 -0.280187 -0.324964 -0.230961       NaN
# 11146  4.848764  5.444819  1.936215  4.896366       NaN
# 11147 -0.260851 -0.125457 -0.324964 -0.230961       NaN
# 11148 -0.260851 -0.125457 -0.324964 -0.230961       NaN
#
# [9364 rows x 5 columns]

# %%
print(gbowl)
# Out:
#            Mdns      Runs      Wkts      Econ       Ave
# 0           NaN -0.315568 -0.170680 -0.389865 -0.135235
# 1           NaN -0.315568 -0.170680 -0.389865 -0.135235
# 2           NaN -0.315568 -0.170680 -0.389865 -0.135235
# 3           NaN -0.315568 -0.170680 -0.389865 -0.135235
# 4           NaN -0.315568 -0.170680 -0.389865 -0.135235
# ...         ...       ...       ...       ...       ...
# 11113 -0.407759  0.545662  0.210617  0.210442  0.148629
# 11114 -0.407759  0.472246  0.210617  0.252480  0.124812
# 11115 -0.407759 -0.922665 -1.206259  3.213820 -1.089838
# 11116 -0.407759 -0.261918  0.919054 -0.476178 -0.439167
# 11117 -0.407759  2.601320 -0.497821  1.345467  2.720829
#
# [9344 rows x 5 columns]

# %%
gbat.to_csv("Batno.csv")

# %%
gbowl.to_csv("Bowlno.csv")

# %%
sns.pairplot(df)

# %%
import matplotlib.pyplot as plt
plt.plot(f,b, '-p', color='gray',
         markersize=0.2, linewidth=0.2,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)

# %%
    index = np.arange(len(a))
    plt.bar(index, b)
    plt.xlabel('Players', fontsize=1)
    plt.ylabel('Runs', fontsize=1)
    plt.xticks(index, b, fontsize=1, rotation=30)
    plt.title('LOL')
    plt.show()

# %%
g1
# Out:
# [['Aaron Finch ', 'Afghanistan'],
#  ['Aaron Finch ', 'Bangladesh'],
#  ['Aaron Finch ', 'England'],
#  ['Aaron Finch ', 'India'],
#  ['Aaron Finch ', 'New Zealand'],
#  ['Aaron Finch ', 'Pakistan'],
#  ['Aaron Finch ', 'South Africa'],
#  ['Aaron Finch ', 'Sri Lanka'],
#  ['Aaron Finch ', 'West Indies'],
#  ['Abid Ali', 'Australia'],
#  ['Abid Ali', 'England'],
#  ['Abu Jayed', 'West Indies'],
#  ['Adam Zampa', 'Bangladesh'],
#  ['Adam Zampa', 'England'],
#  ['Adam Zampa', 'India'],
#  ['Adam Zampa', 'New Zealand'],
#  ['Adam Zampa', 'Pakistan'],
#  ['Adam Zampa', 'South Africa'],
#  ['Adam Zampa', 'Sri Lanka'],
#  ['Adam Zampa', 'West Indies'],
#  ['Adil Rashid', 'Australia'],
#  ['Adil Rashid', 'Bangladesh'],
#  ['Adil Rashid', 'India'],
#  ['Adil Rashid', 'New Zealand'],
#  ['Adil Rashid', 'Pakistan'],
#  ['Adil Rashid', 'South Africa'],
#  ['Adil Rashid', 'Sri Lanka'],
#  ['Adil Rashid', 'West Indies'],
#  ['Aftab Alam', 'Bangladesh'],
#  ['Aftab Alam', 'India'],
#  ['Aftab Alam', 'Pakistan'],
#  ['Aftab Alam', 'Sri Lanka'],
#  ['Aiden Markram', 'Australia'],
#  ['Aiden Markram', 'Bangladesh'],
#  ['Aiden Markram', 'India'],
#  ['Aiden Markram', 'Sri Lanka'],
#  ['Alex Carey ', 'England'],
#  ['Alex Carey ', 'India'],
#  ['Alex Carey ', 'Pakistan'],
#  ['Alex Carey ', 'South Africa'],
#  ['Alex Hales', 'Afghanistan'],
#  ['Alex Hales', 'Australia'],
#  ['Alex Hales', 'Bangladesh'],
#  ['Alex Hales', 'India'],
#  ['Alex Hales', 'New Zealand'],
#  ['Alex Hales', 'Pakistan'],
#  ['Alex Hales', 'South Africa'],
#  ['Alex Hales', 'Sri Lanka'],
#  ['Alex Hales', 'West Indies'],
#  ['Andile Phehlukwayo', 'Australia'],
#  ['Andile Phehlukwayo', 'Bangladesh'],
#  ['Andile Phehlukwayo', 'England'],
#  ['Andile Phehlukwayo', 'India'],
#  ['Andile Phehlukwayo', 'New Zealand'],
#  ['Andile Phehlukwayo', 'Pakistan'],
#  ['Andile Phehlukwayo', 'Sri Lanka'],
#  ['Andre Russell', 'Australia'],
#  ['Andre Russell', 'Bangladesh'],
#  ['Andre Russell', 'England'],
#  ['Andre Russell', 'India'],
#  ['Andre Russell', 'New Zealand'],
#  ['Andre Russell', 'Pakistan'],
#  ['Andre Russell', 'South Africa'],
#  ['Andre Russell', 'Sri Lanka'],
#  ['Angelo Mathews', 'Afghanistan'],
#  ['Angelo Mathews', 'Australia'],
#  ['Angelo Mathews', 'Bangladesh'],
#  ['Angelo Mathews', 'England'],
#  ['Angelo Mathews', 'India'],
#  ['Angelo Mathews', 'New Zealand'],
#  ['Angelo Mathews', 'Pakistan'],
#  ['Angelo Mathews', 'South Africa'],
#  ['Angelo Mathews', 'West Indies'],
#  ['Anrich Nortje', 'Sri Lanka'],
#  ['Asghar Afghan', 'Australia'],
#  ['Asghar Afghan', 'Bangladesh'],
#  ['Asghar Afghan', 'India'],
#  ['Asghar Afghan', 'New Zealand'],
#  ['Asghar Afghan', 'Pakistan'],
#  ['Asghar Afghan', 'Sri Lanka'],
#  ['Asghar Afghan', 'West Indies'],
#  ['Ashley Nurse', 'Afghanistan'],
#  ['Ashley Nurse', 'Bangladesh'],
#  ['Ashley Nurse', 'England'],
#  ['Ashley Nurse', 'India'],
#  ['Ashley Nurse', 'New Zealand'],
#  ['Ashley Nurse', 'Pakistan'],
#  ['Ashley Nurse', 'Sri Lanka'],
#  ['Avishka Fernando', 'Australia'],
#  ['Avishka Fernando', 'South Africa'],
#  ['Babar Azam ', 'Afghanistan'],
#  ['Babar Azam ', 'Australia'],
#  ['Babar Azam ', 'Bangladesh'],
#  ['Babar Azam ', 'England'],
#  ['Babar Azam ', 'India'],
#  ['Babar Azam ', 'New Zealand'],
#  ['Babar Azam ', 'South Africa'],
#  ['Babar Azam ', 'Sri Lanka'],
#  ['Babar Azam ', 'West Indies'],
#  ['Ben Stokes', 'Australia'],
#  ['Ben Stokes', 'Bangladesh'],
#  ['Ben Stokes', 'India'],
#  ['Ben Stokes', 'New Zealand'],
#  ['Ben Stokes', 'Pakistan'],
#  ['Ben Stokes', 'South Africa'],
#  ['Ben Stokes', 'Sri Lanka'],
#  ['Ben Stokes', 'West Indies'],
#  ['Bhuvneshwar Kumar', 'Afghanistan'],
#  ['Bhuvneshwar Kumar', 'Australia'],
#  ['Bhuvneshwar Kumar', 'Bangladesh'],
#  ['Bhuvneshwar Kumar', 'England'],
#  ['Bhuvneshwar Kumar', 'New Zealand'],
#  ['Bhuvneshwar Kumar', 'Pakistan'],
#  ['Bhuvneshwar Kumar', 'South Africa'],
#  ['Bhuvneshwar Kumar', 'Sri Lanka'],
#  ['Bhuvneshwar Kumar', 'West Indies'],
#  ['Carlos Brathwaite', 'Afghanistan'],
#  ['Carlos Brathwaite', 'Australia'],
#  ['Carlos Brathwaite', 'Bangladesh'],
#  ['Carlos Brathwaite', 'England'],
#  ['Carlos Brathwaite', 'Pakistan'],
#  ['Carlos Brathwaite', 'South Africa'],
#  ['Carlos Brathwaite', 'Sri Lanka'],
#  ['Chris Gayle ', 'Afghanistan'],
#  ['Chris Gayle ', 'Australia'],
#  ['Chris Gayle ', 'Bangladesh'],
#  ['Chris Gayle ', 'England'],
#  ['Chris Gayle ', 'India'],
#  ['Chris Gayle ', 'New Zealand'],
#  ['Chris Gayle ', 'Pakistan'],
#  ['Chris Gayle ', 'South Africa'],
#  ['Chris Gayle ', 'Sri Lanka'],
#  ['Chris Morris', 'Australia'],
#  ['Chris Morris', 'Bangladesh'],
#  ['Chris Morris', 'England'],
#  ['Chris Morris', 'India'],
#  ['Chris Morris', 'New Zealand'],
#  ['Chris Morris', 'Pakistan'],
#  ['Chris Morris', 'Sri Lanka'],
#  ['Chris Morris', 'West Indies'],
#  ['Chris Woakes', 'Australia'],
#  ['Chris Woakes', 'Bangladesh'],
#  ['Chris Woakes', 'India'],
#  ['Chris Woakes', 'New Zealand'],
#  ['Chris Woakes', 'Pakistan'],
#  ['Chris Woakes', 'South Africa'],
#  ['Chris Woakes', 'Sri Lanka'],
#  ['Chris Woakes', 'West Indies'],
#  ['Colin Munro', 'Australia'],
#  ['Colin Munro', 'Bangladesh'],
#  ['Colin Munro', 'England'],
#  ['Colin Munro', 'India'],
#  ['Colin Munro', 'Pakistan'],
#  ['Colin Munro', 'South Africa'],
#  ['Colin Munro', 'Sri Lanka'],
#  ['Colin Munro', 'West Indies'],
#  ['Colin de Grandhomme', 'Australia'],
#  ['Colin de Grandhomme', 'Bangladesh'],
#  ['Colin de Grandhomme', 'England'],
#  ['Colin de Grandhomme', 'India'],
#  ['Colin de Grandhomme', 'Pakistan'],
#  ['Colin de Grandhomme', 'South Africa'],
#  ['Dale Steyn', 'Australia'],
#  ['Dale Steyn', 'Bangladesh'],
#  ['Dale Steyn', 'England'],
#  ['Dale Steyn', 'India'],
#  ['Dale Steyn', 'New Zealand'],
#  ['Dale Steyn', 'Pakistan'],
#  ['Dale Steyn', 'Sri Lanka'],
#  ['Dale Steyn', 'West Indies'],
#  ['Darren Bravo', 'Australia'],
#  ['Darren Bravo', 'Bangladesh'],
#  ['Darren Bravo', 'England'],
#  ['Darren Bravo', 'India'],
#  ['Darren Bravo', 'New Zealand'],
#  ['Darren Bravo', 'Pakistan'],
#  ['Darren Bravo', 'South Africa'],
#  ['Darren Bravo', 'Sri Lanka'],
#  ['David Miller', 'Australia'],
#  ['David Miller', 'Bangladesh'],
#  ['David Miller', 'England'],
#  ['David Miller', 'India'],
#  ['David Miller', 'New Zealand'],
#  ['David Miller', 'Pakistan'],
#  ['David Miller', 'Sri Lanka'],
#  ['David Miller', 'West Indies'],
#  ['David Warner', 'Afghanistan'],
#  ['David Warner', 'Bangladesh'],
#  ['David Warner', 'England'],
#  ['David Warner', 'India'],
#  ['David Warner', 'New Zealand'],
#  ['David Warner', 'Pakistan'],
#  ['David Warner', 'South Africa'],
#  ['David Warner', 'Sri Lanka'],
#  ['David Warner', 'West Indies'],
#  ['David Willey', 'Australia'],
#  ['David Willey', 'Bangladesh'],
#  ['David Willey', 'India'],
#  ['David Willey', 'New Zealand'],
#  ['David Willey', 'Pakistan'],
#  ['David Willey', 'South Africa'],
#  ['David Willey', 'Sri Lanka'],
#  ['David Willey', 'West Indies'],
#  ['Dawlat Zadran', 'Australia'],
#  ['Dawlat Zadran', 'Bangladesh'],
#  ['Dawlat Zadran', 'England'],
#  ['Dawlat Zadran', 'India'],
#  ['Dawlat Zadran', 'New Zealand'],
#  ['Dawlat Zadran', 'Pakistan'],
#  ['Dawlat Zadran', 'Sri Lanka'],
#  ['Dawlat Zadran', 'West Indies'],
#  ['Dhananjaya de Silva ', 'Afghanistan'],
#  ['Dhananjaya de Silva ', 'Australia'],
#  ['Dhananjaya de Silva ', 'Bangladesh'],
#  ['Dhananjaya de Silva ', 'England'],
#  ['Dhananjaya de Silva ', 'New Zealand'],
#  ['Dhananjaya de Silva ', 'Pakistan'],
#  ['Dhananjaya de Silva ', 'South Africa'],
#  ['Dhananjaya de Silva ', 'West Indies'],
#  ['Dimuth Karunaratne ', 'Afghanistan'],
#  ['Dimuth Karunaratne ', 'Bangladesh'],
#  ['Dimuth Karunaratne ', 'England'],
#  ['Dimuth Karunaratne ', 'New Zealand'],
#  ['Dimuth Karunaratne ', 'Pakistan'],
#  ['Dinesh Karthik', 'Afghanistan'],
#  ['Dinesh Karthik', 'Australia'],
#  ['Dinesh Karthik', 'Bangladesh'],
#  ['Dinesh Karthik', 'England'],
#  ['Dinesh Karthik', 'New Zealand'],
#  ['Dinesh Karthik', 'Pakistan'],
#  ['Dinesh Karthik', 'South Africa'],
#  ['Dinesh Karthik', 'Sri Lanka'],
#  ['Dinesh Karthik', 'West Indies'],
#  ['Dwaine Pretorius', 'Australia'],
#  ['Dwaine Pretorius', 'Bangladesh'],
#  ['Dwaine Pretorius', 'England'],
#  ['Dwaine Pretorius', 'New Zealand'],
#  ['Dwaine Pretorius', 'Pakistan'],
#  ['Dwaine Pretorius', 'Sri Lanka'],
#  ['Eoin Morgan ', 'Afghanistan'],
#  ['Eoin Morgan ', 'Australia'],
#  ['Eoin Morgan ', 'Bangladesh'],
#  ['Eoin Morgan ', 'England'],
#  ['Eoin Morgan ', 'India'],
#  ['Eoin Morgan ', 'New Zealand'],
#  ['Eoin Morgan ', 'Pakistan'],
#  ['Eoin Morgan ', 'South Africa'],
#  ['Eoin Morgan ', 'Sri Lanka'],
#  ['Eoin Morgan ', 'West Indies'],
#  ['Evin Lewis', 'Afghanistan'],
#  ['Evin Lewis', 'Bangladesh'],
#  ['Evin Lewis', 'England'],
#  ['Evin Lewis', 'India'],
#  ['Evin Lewis', 'New Zealand'],
#  ['Evin Lewis', 'Pakistan'],
#  ['Evin Lewis', 'Sri Lanka'],
#  ['Fabian Allen', 'Bangladesh'],
#  ['Fabian Allen', 'India'],
#  ['Faf du Plessis ', 'Australia'],
#  ['Faf du Plessis ', 'Bangladesh'],
#  ['Faf du Plessis ', 'England'],
#  ['Faf du Plessis ', 'India'],
#  ['Faf du Plessis ', 'New Zealand'],
#  ['Faf du Plessis ', 'Pakistan'],
#  ['Faf du Plessis ', 'Sri Lanka'],
#  ['Faf du Plessis ', 'West Indies'],
#  ['Faheem Ashraf', 'Australia'],
#  ['Faheem Ashraf', 'England'],
#  ['Faheem Ashraf', 'India'],
#  ['Faheem Ashraf', 'New Zealand'],
#  ['Faheem Ashraf', 'South Africa'],
#  ['Faheem Ashraf', 'Sri Lanka'],
#  ['Fakhar Zaman', 'Afghanistan'],
#  ['Fakhar Zaman', 'Bangladesh'],
#  ['Fakhar Zaman', 'England'],
#  ['Fakhar Zaman', 'India'],
#  ['Fakhar Zaman', 'New Zealand'],
#  ['Fakhar Zaman', 'South Africa'],
#  ['Fakhar Zaman', 'Sri Lanka'],
#  ['Glenn Maxwell', 'Afghanistan'],
#  ['Glenn Maxwell', 'Bangladesh'],
#  ['Glenn Maxwell', 'England'],
#  ['Glenn Maxwell', 'India'],
#  ['Glenn Maxwell', 'New Zealand'],
#  ['Glenn Maxwell', 'Pakistan'],
#  ['Glenn Maxwell', 'South Africa'],
#  ['Glenn Maxwell', 'Sri Lanka'],
#  ['Glenn Maxwell', 'West Indies'],
#  ['Gulbadin Naib ', 'Australia'],
#  ['Gulbadin Naib ', 'Bangladesh'],
#  ['Gulbadin Naib ', 'India'],
#  ['Gulbadin Naib ', 'Pakistan'],
#  ['Gulbadin Naib ', 'Sri Lanka'],
#  ['Gulbadin Naib ', 'West Indies'],
#  ['Hamid Hassan', 'Australia'],
#  ['Hamid Hassan', 'Bangladesh'],
#  ['Hamid Hassan', 'England'],
#  ['Hamid Hassan', 'New Zealand'],
#  ['Hamid Hassan', 'Sri Lanka'],
#  ['Hardik Pandya', 'Australia'],
#  ['Hardik Pandya', 'Bangladesh'],
#  ['Hardik Pandya', 'England'],
#  ['Hardik Pandya', 'New Zealand'],
#  ['Hardik Pandya', 'Pakistan'],
#  ['Hardik Pandya', 'South Africa'],
#  ['Hardik Pandya', 'Sri Lanka'],
#  ['Hardik Pandya', 'West Indies'],
#  ['Haris Sohail', 'Afghanistan'],
#  ['Haris Sohail', 'Australia'],
#  ['Haris Sohail', 'Bangladesh'],
#  ['Haris Sohail', 'England'],
#  ['Haris Sohail', 'India'],
#  ['Haris Sohail', 'New Zealand'],
#  ['Haris Sohail', 'West Indies'],
#  ['Hasan Ali', 'Afghanistan'],
#  ['Hasan Ali', 'Australia'],
#  ['Hasan Ali', 'Bangladesh'],
#  ['Hasan Ali', 'England'],
#  ['Hasan Ali', 'India'],
#  ['Hasan Ali', 'New Zealand'],
#  ['Hasan Ali', 'South Africa'],
#  ['Hasan Ali', 'Sri Lanka'],
#  ['Hasan Ali', 'West Indies'],
#  ['Hashim Amla', 'Australia'],
#  ['Hashim Amla', 'Bangladesh'],
#  ['Hashim Amla', 'England'],
#  ['Hashim Amla', 'India'],
#  ['Hashim Amla', 'New Zealand'],
#  ['Hashim Amla', 'Pakistan'],
#  ['Hashim Amla', 'Sri Lanka'],
#  ['Hashim Amla', 'West Indies'],
#  ['Hashmatullah Shahidi', 'Bangladesh'],
#  ['Hashmatullah Shahidi', 'India'],
#  ['Hashmatullah Shahidi', 'Pakistan'],
#  ['Hashmatullah Shahidi', 'Sri Lanka'],
#  ['Henry Nicholls', 'Australia'],
#  ['Henry Nicholls', 'Bangladesh'],
#  ['Henry Nicholls', 'England'],
#  ['Henry Nicholls', 'India'],
#  ['Henry Nicholls', 'Pakistan'],
#  ['Henry Nicholls', 'Sri Lanka'],
#  ['Henry Nicholls', 'West Indies'],
#  ['Imad Wasim', 'Australia'],
#  ['Imad Wasim', 'England'],
#  ['Imad Wasim', 'India'],
#  ['Imad Wasim', 'New Zealand'],
#  ['Imad Wasim', 'South Africa'],
#  ['Imad Wasim', 'Sri Lanka'],
#  ['Imad Wasim', 'West Indies'],
#  ['Imam-ul-Haq', 'Afghanistan'],
#  ['Imam-ul-Haq', 'Australia'],
#  ['Imam-ul-Haq', 'Bangladesh'],
#  ['Imam-ul-Haq', 'England'],
#  ['Imam-ul-Haq', 'India'],
#  ['Imam-ul-Haq', 'New Zealand'],
#  ['Imam-ul-Haq', 'South Africa'],
#  ['Imam-ul-Haq', 'Sri Lanka'],
#  ['Imran Tahir', 'Australia'],
#  ['Imran Tahir', 'Bangladesh'],
#  ['Imran Tahir', 'England'],
#  ['Imran Tahir', 'India'],
#  ['Imran Tahir', 'New Zealand'],
#  ['Imran Tahir', 'Pakistan'],
#  ['Imran Tahir', 'Sri Lanka'],
#  ['Imran Tahir', 'West Indies'],
#  ['Ish Sodhi', 'Australia'],
#  ['Ish Sodhi', 'Bangladesh'],
#  ['Ish Sodhi', 'England'],
#  ['Ish Sodhi', 'India'],
#  ['Ish Sodhi', 'Pakistan'],
#  ['Ish Sodhi', 'South Africa'],
#  ['Ish Sodhi', 'Sri Lanka'],
#  ['Isuru Udana', 'India'],
#  ['Isuru Udana', 'South Africa'],
#  ['JP Duminy', 'Australia'],
#  ['JP Duminy', 'Bangladesh'],
#  ['JP Duminy', 'England'],
#  ['JP Duminy', 'India'],
#  ['JP Duminy', 'New Zealand'],
#  ['JP Duminy', 'Pakistan'],
#  ['JP Duminy', 'Sri Lanka'],
#  ['JP Duminy', 'West Indies'],
#  ['James Neesham', 'Australia'],
#  ['James Neesham', 'Bangladesh'],
#  ['James Neesham', 'England'],
#  ['James Neesham', 'India'],
#  ['James Neesham', 'Pakistan'],
#  ['James Neesham', 'South Africa'],
#  ['James Neesham', 'Sri Lanka'],
#  ['James Neesham', 'West Indies'],
#  ['Jason Behrendorff', 'India'],
#  ['Jason Behrendorff', 'Pakistan'],
#  ['Jason Holder ', 'Afghanistan'],
#  ['Jason Holder ', 'Australia'],
#  ['Jason Holder ', 'Bangladesh'],
#  ['Jason Holder ', 'England'],
#  ['Jason Holder ', 'India'],
#  ['Jason Holder ', 'New Zealand'],
#  ['Jason Holder ', 'Pakistan'],
#  ['Jason Holder ', 'South Africa'],
#  ['Jason Holder ', 'Sri Lanka'],
#  ['Jason Roy', 'Australia'],
#  ['Jason Roy', 'Bangladesh'],
#  ['Jason Roy', 'India'],
#  ['Jason Roy', 'New Zealand'],
#  ['Jason Roy', 'Pakistan'],
#  ['Jason Roy', 'South Africa'],
#  ['Jason Roy', 'Sri Lanka'],
#  ['Jason Roy', 'West Indies'],
#  ['Jasprit Bumrah', 'Australia'],
#  ['Jasprit Bumrah', 'Bangladesh'],
#  ['Jasprit Bumrah', 'England'],
#  ['Jasprit Bumrah', 'New Zealand'],
#  ['Jasprit Bumrah', 'Pakistan'],
#  ['Jasprit Bumrah', 'South Africa'],
#  ['Jasprit Bumrah', 'Sri Lanka'],
#  ['Jasprit Bumrah', 'West Indies'],
#  ['Jeevan Mendis', 'Afghanistan'],
#  ['Jeevan Mendis', 'Australia'],
#  ['Jeevan Mendis', 'Bangladesh'],
#  ['Jeevan Mendis', 'England'],
#  ['Jeevan Mendis', 'India'],
#  ['Jeevan Mendis', 'New Zealand'],
#  ['Jeevan Mendis', 'Pakistan'],
#  ['Jeevan Mendis', 'West Indies'],
#  ['Jeffrey Vandersay', 'New Zealand'],
#  ['Jeffrey Vandersay', 'Pakistan'],
#  ['Jeffrey Vandersay', 'South Africa'],
#  ['Jhye Richardson', 'England'],
#  ['Jhye Richardson', 'India'],
#  ['Jhye Richardson', 'Pakistan'],
#  ['Joe Denly', 'Australia'],
#  ['Joe Denly', 'New Zealand'],
#  ['Joe Denly', 'Pakistan'],
#  ['Joe Denly', 'South Africa'],
#  ['Joe Denly', 'Sri Lanka'],
#  ['Joe Root', 'Afghanistan'],
#  ['Joe Root', 'Australia'],
#  ['Joe Root', 'Bangladesh'],
#  ['Joe Root', 'India'],
#  ['Joe Root', 'New Zealand'],
#  ['Joe Root', 'Pakistan'],
#  ['Joe Root', 'South Africa'],
#  ['Joe Root', 'Sri Lanka'],
#  ['Joe Root', 'West Indies'],
#  ['Jonny Bairstow', 'Australia'],
#  ['Jonny Bairstow', 'Bangladesh'],
#  ['Jonny Bairstow', 'India'],
#  ['Jonny Bairstow', 'New Zealand'],
#  ['Jonny Bairstow', 'Pakistan'],
#  ['Jonny Bairstow', 'South Africa'],
#  ['Jonny Bairstow', 'Sri Lanka'],
#  ['Jonny Bairstow', 'West Indies'],
#  ['Jos Buttler ', 'Afghanistan'],
#  ['Jos Buttler ', 'Australia'],
#  ['Jos Buttler ', 'Bangladesh'],
#  ['Jos Buttler ', 'India'],
#  ['Jos Buttler ', 'New Zealand'],
#  ['Jos Buttler ', 'Pakistan'],
#  ['Jos Buttler ', 'South Africa'],
#  ['Jos Buttler ', 'Sri Lanka'],
#  ['Jos Buttler ', 'West Indies'],
#  ['Junaid Khan', 'Afghanistan'],
#  ['Junaid Khan', 'Australia'],
#  ['Junaid Khan', 'Bangladesh'],
#  ['Junaid Khan', 'England'],
#  ['Junaid Khan', 'India'],
#  ['Junaid Khan', 'New Zealand'],
#  ['Junaid Khan', 'South Africa'],
#  ['Junaid Khan', 'Sri Lanka'],
#  ['Junaid Khan', 'West Indies'],
#  ['K. L. Rahul', 'Afghanistan'],
#  ['K. L. Rahul', 'Australia'],
#  ['K. L. Rahul', 'England'],
#  ['K. L. Rahul', 'Sri Lanka'],
#  ['Kagiso Rabada', 'Australia'],
#  ['Kagiso Rabada', 'Bangladesh'],
#  ['Kagiso Rabada', 'England'],
#  ['Kagiso Rabada', 'India'],
#  ['Kagiso Rabada', 'New Zealand'],
#  ['Kagiso Rabada', 'Pakistan'],
#  ['Kagiso Rabada', 'Sri Lanka'],
#  ['Kagiso Rabada', 'West Indies'],
#  ['Kane Richardson', 'England'],
#  ['Kane Richardson', 'India'],
#  ['Kane Richardson', 'New Zealand'],
#  ['Kane Richardson', 'Pakistan'],
#  ['Kane Richardson', 'South Africa'],
#  ['Kane Richardson', 'Sri Lanka'],
#  ['Kane Williamson ', 'Afghanistan'],
#  ['Kane Williamson ', 'Australia'],
#  ['Kane Williamson ', 'Bangladesh'],
#  ['Kane Williamson ', 'England'],
#  ['Kane Williamson ', 'India'],
#  ['Kane Williamson ', 'Pakistan'],
#  ['Kane Williamson ', 'South Africa'],
#  ['Kane Williamson ', 'Sri Lanka'],
#  ['Kane Williamson ', 'West Indies'],
#  ['Kedar Jadhav', 'Afghanistan'],
#  ['Kedar Jadhav', 'Australia'],
#  ['Kedar Jadhav', 'Bangladesh'],
#  ['Kedar Jadhav', 'England'],
#  ['Kedar Jadhav', 'New Zealand'],
#  ['Kedar Jadhav', 'Pakistan'],
#  ['Kedar Jadhav', 'South Africa'],
#  ['Kedar Jadhav', 'Sri Lanka'],
#  ['Kedar Jadhav', 'West Indies'],
#  ['Kemar Roach', 'Afghanistan'],
#  ['Kemar Roach', 'Australia'],
#  ['Kemar Roach', 'Bangladesh'],
#  ['Kemar Roach', 'England'],
#  ['Kemar Roach', 'India'],
#  ['Kemar Roach', 'Pakistan'],
#  ['Kemar Roach', 'South Africa'],
#  ['Kemar Roach', 'Sri Lanka'],
#  ['Kuldeep Yadav', 'Afghanistan'],
#  ['Kuldeep Yadav', 'Australia'],
#  ['Kuldeep Yadav', 'Bangladesh'],
#  ['Kuldeep Yadav', 'England'],
#  ['Kuldeep Yadav', 'New Zealand'],
#  ['Kuldeep Yadav', 'Pakistan'],
#  ['Kuldeep Yadav', 'South Africa'],
#  ['Kuldeep Yadav', 'Sri Lanka'],
#  ['Kuldeep Yadav', 'West Indies'],
#  ['Kusal Mendis', 'Afghanistan'],
#  ['Kusal Mendis', 'Australia'],
#  ['Kusal Mendis', 'Bangladesh'],
#  ['Kusal Mendis', 'England'],
#  ['Kusal Mendis', 'India'],
#  ['Kusal Mendis', 'New Zealand'],
#  ['Kusal Mendis', 'Pakistan'],
#  ['Kusal Mendis', 'South Africa'],
#  ['Kusal Mendis', 'West Indies'],
#  ['Kusal Perera ', 'Afghanistan'],
#  ['Kusal Perera ', 'Australia'],
#  ['Kusal Perera ', 'Bangladesh'],
#  ['Kusal Perera ', 'England'],
#  ['Kusal Perera ', 'India'],
#  ['Kusal Perera ', 'New Zealand'],
#  ['Kusal Perera ', 'Pakistan'],
#  ['Kusal Perera ', 'South Africa'],
#  ['Kusal Perera ', 'West Indies'],
#  ['Lahiru Thirimanne', 'Afghanistan'],
#  ['Lahiru Thirimanne', 'Australia'],
#  ['Lahiru Thirimanne', 'Bangladesh'],
#  ['Lahiru Thirimanne', 'England'],
#  ['Lahiru Thirimanne', 'India'],
#  ['Lahiru Thirimanne', 'New Zealand'],
#  ['Lahiru Thirimanne', 'Pakistan'],
#  ['Lahiru Thirimanne', 'South Africa'],
#  ['Lahiru Thirimanne', 'West Indies'],
#  ['Lasith Malinga', 'Afghanistan'],
#  ['Lasith Malinga', 'Australia'],
#  ['Lasith Malinga', 'Bangladesh'],
#  ['Lasith Malinga', 'England'],
#  ['Lasith Malinga', 'India'],
#  ['Lasith Malinga', 'New Zealand'],
#  ['Lasith Malinga', 'Pakistan'],
#  ['Lasith Malinga', 'South Africa'],
#  ['Lasith Malinga', 'West Indies'],
#  ['Liam Plunkett', 'Australia'],
#  ['Liam Plunkett', 'Bangladesh'],
#  ['Liam Plunkett', 'India'],
#  ['Liam Plunkett', 'New Zealand'],
#  ['Liam Plunkett', 'Pakistan'],
#  ['Liam Plunkett', 'South Africa'],
#  ['Liam Plunkett', 'Sri Lanka'],
#  ['Liam Plunkett', 'West Indies'],
#  ['Liton Das', 'Afghanistan'],
#  ['Liton Das', 'India'],
#  ['Liton Das', 'New Zealand'],
#  ['Liton Das', 'Pakistan'],
#  ['Liton Das', 'South Africa'],
#  ['Liton Das', 'Sri Lanka'],
#  ['Liton Das', 'West Indies'],
#  ['Lockie Ferguson', 'Australia'],
#  ['Lockie Ferguson', 'Bangladesh'],
#  ['Lockie Ferguson', 'England'],
#  ['Lockie Ferguson', 'India'],
#  ['Lockie Ferguson', 'Pakistan'],
#  ['Lockie Ferguson', 'South Africa'],
#  ['Lockie Ferguson', 'Sri Lanka'],
#  ['Lockie Ferguson', 'West Indies'],
#  ['Lungi Ngidi', 'Australia'],
#  ['Lungi Ngidi', 'India'],
#  ['Lungi Ngidi', 'Sri Lanka'],
#  ['MS Dhoni ', 'Afghanistan'],
#  ['MS Dhoni ', 'Australia'],
#  ['MS Dhoni ', 'Bangladesh'],
#  ['MS Dhoni ', 'England'],
#  ['MS Dhoni ', 'New Zealand'],
#  ['MS Dhoni ', 'Pakistan'],
#  ['MS Dhoni ', 'South Africa'],
#  ['MS Dhoni ', 'Sri Lanka'],
#  ['MS Dhoni ', 'West Indies'],
#  ['Mahmudullah', 'Afghanistan'],
#  ['Mahmudullah', 'Australia'],
#  ['Mahmudullah', 'England'],
#  ['Mahmudullah', 'India'],
#  ['Mahmudullah', 'New Zealand'],
#  ['Mahmudullah', 'Pakistan'],
#  ['Mahmudullah', 'South Africa'],
#  ['Mahmudullah', 'Sri Lanka'],
#  ['Mahmudullah', 'West Indies'],
#  ['Marcus Stoinis', 'England'],
#  ['Marcus Stoinis', 'India'],
#  ['Marcus Stoinis', 'New Zealand'],
#  ['Marcus Stoinis', 'Pakistan'],
#  ['Marcus Stoinis', 'South Africa'],
#  ['Mark Wood', 'Australia'],
#  ['Mark Wood', 'Bangladesh'],
#  ['Mark Wood', 'India'],
#  ['Mark Wood', 'New Zealand'],
#  ['Mark Wood', 'Pakistan'],
#  ['Mark Wood', 'South Africa'],
#  ['Mark Wood', 'Sri Lanka'],
#  ['Mark Wood', 'West Indies'],
#  ['Martin Guptill', 'Afghanistan'],
#  ['Martin Guptill', 'Australia'],
#  ['Martin Guptill', 'Bangladesh'],
#  ['Martin Guptill', 'England'],
#  ['Martin Guptill', 'India'],
#  ['Martin Guptill', 'Pakistan'],
#  ['Martin Guptill', 'South Africa'],
#  ['Martin Guptill', 'Sri Lanka'],
#  ['Martin Guptill', 'West Indies'],
#  ['Mashrafe Mortaza ', 'Afghanistan'],
#  ['Mashrafe Mortaza ', 'Australia'],
#  ['Mashrafe Mortaza ', 'England'],
#  ['Mashrafe Mortaza ', 'India'],
#  ['Mashrafe Mortaza ', 'New Zealand'],
#  ['Mashrafe Mortaza ', 'Pakistan'],
#  ['Mashrafe Mortaza ', 'South Africa'],
#  ['Mashrafe Mortaza ', 'Sri Lanka'],
#  ['Mashrafe Mortaza ', 'West Indies'],
#  ['Matt Henry', 'Australia'],
#  ['Matt Henry', 'Bangladesh'],
#  ['Matt Henry', 'England'],
#  ['Matt Henry', 'India'],
#  ['Matt Henry', 'Pakistan'],
#  ['Matt Henry', 'South Africa'],
#  ['Matt Henry', 'Sri Lanka'],
#  ['Matt Henry', 'West Indies'],
#  ['Milinda Siriwardana', 'Australia'],
#  ['Milinda Siriwardana', 'Bangladesh'],
#  ['Milinda Siriwardana', 'India'],
#  ['Milinda Siriwardana', 'New Zealand'],
#  ['Milinda Siriwardana', 'Pakistan'],
#  ['Milinda Siriwardana', 'West Indies'],
#  ['Mitchell Santner', 'Australia'],
#  ['Mitchell Santner', 'Bangladesh'],
#  ['Mitchell Santner', 'England'],
#  ['Mitchell Santner', 'India'],
#  ['Mitchell Santner', 'Pakistan'],
#  ['Mitchell Santner', 'South Africa'],
#  ['Mitchell Santner', 'Sri Lanka'],
#  ['Mitchell Santner', 'West Indies'],
#  ['Mitchell Starc', 'Afghanistan'],
#  ['Mitchell Starc', 'Bangladesh'],
#  ['Mitchell Starc', 'England'],
#  ['Mitchell Starc', 'India'],
#  ['Mitchell Starc', 'New Zealand'],
#  ['Mitchell Starc', 'Pakistan'],
#  ['Mitchell Starc', 'South Africa'],
#  ['Mitchell Starc', 'Sri Lanka'],
#  ['Mitchell Starc', 'West Indies'],
#  ['Moeen Ali', 'Australia'],
#  ['Moeen Ali', 'Bangladesh'],
#  ['Moeen Ali', 'India'],
#  ['Moeen Ali', 'New Zealand'],
#  ['Moeen Ali', 'Pakistan'],
#  ['Moeen Ali', 'South Africa'],
#  ['Moeen Ali', 'Sri Lanka'],
#  ['Moeen Ali', 'West Indies'],
#  ['Mohammad Hafeez', 'Afghanistan'],
#  ['Mohammad Hafeez', 'Australia'],
#  ['Mohammad Hafeez', 'Bangladesh'],
#  ['Mohammad Hafeez', 'England'],
#  ['Mohammad Hafeez', 'India'],
#  ['Mohammad Hafeez', 'New Zealand'],
#  ['Mohammad Hafeez', 'South Africa'],
#  ['Mohammad Hafeez', 'Sri Lanka'],
#  ['Mohammad Hafeez', 'West Indies'],
#  ['Mohammad Hasnain', 'Australia'],
#  ['Mohammad Hasnain', 'England'],
#  ['Mohammad Mithun', 'Afghanistan'],
#  ['Mohammad Mithun', 'India'],
#  ['Mohammad Mithun', 'New Zealand'],
#  ['Mohammad Mithun', 'Pakistan'],
#  ['Mohammad Mithun', 'Sri Lanka'],
#  ['Mohammad Mithun', 'West Indies'],
#  ['Mohammad Nabi', 'Australia'],
#  ['Mohammad Nabi', 'Bangladesh'],
#  ['Mohammad Nabi', 'England'],
#  ['Mohammad Nabi', 'India'],
#  ['Mohammad Nabi', 'New Zealand'],
#  ['Mohammad Nabi', 'Pakistan'],
#  ['Mohammad Nabi', 'Sri Lanka'],
#  ['Mohammad Nabi', 'West Indies'],
#  ['Mohammad Saifuddin', 'New Zealand'],
#  ['Mohammad Saifuddin', 'South Africa'],
#  ['Mohammad Saifuddin', 'Sri Lanka'],
#  ['Mohammad Saifuddin', 'West Indies'],
#  ['Mohammad Shahzad ', 'Australia'],
#  ['Mohammad Shahzad ', 'Bangladesh'],
#  ['Mohammad Shahzad ', 'India'],
#  ['Mohammad Shahzad ', 'Pakistan'],
#  ['Mohammad Shahzad ', 'Sri Lanka'],
#  ['Mohammad Shahzad ', 'West Indies'],
#  ['Mohammed Shami', 'Afghanistan'],
#  ['Mohammed Shami', 'Australia'],
#  ['Mohammed Shami', 'Bangladesh'],
#  ['Mohammed Shami', 'England'],
#  ['Mohammed Shami', 'New Zealand'],
#  ['Mohammed Shami', 'Pakistan'],
#  ['Mohammed Shami', 'South Africa'],
#  ['Mohammed Shami', 'Sri Lanka'],
#  ['Mohammed Shami', 'West Indies'],
#  ['Mosaddek Hossain', 'Afghanistan'],
#  ['Mosaddek Hossain', 'England'],
#  ['Mosaddek Hossain', 'India'],
#  ['Mosaddek Hossain', 'New Zealand'],
#  ['Mosaddek Hossain', 'Sri Lanka'],
#  ['Mosaddek Hossain', 'West Indies'],
#  ['Mujeeb Ur Rahman', 'Bangladesh'],
#  ['Mujeeb Ur Rahman', 'India'],
#  ['Mujeeb Ur Rahman', 'Pakistan'],
#  ['Mujeeb Ur Rahman', 'Sri Lanka'],
#  ['Mujeeb Ur Rahman', 'West Indies'],
#  ['Mushfiqur Rahim ', 'Afghanistan'],
#  ['Mushfiqur Rahim ', 'Australia'],
#  ['Mushfiqur Rahim ', 'England'],
#  ['Mushfiqur Rahim ', 'India'],
#  ['Mushfiqur Rahim ', 'New Zealand'],
#  ['Mushfiqur Rahim ', 'Pakistan'],
#  ['Mushfiqur Rahim ', 'South Africa'],
#  ['Mushfiqur Rahim ', 'Sri Lanka'],
#  ['Mushfiqur Rahim ', 'West Indies'],
#  ['Mustafizur Rahman', 'Afghanistan'],
#  ['Mustafizur Rahman', 'Australia'],
#  ['Mustafizur Rahman', 'England'],
#  ['Mustafizur Rahman', 'India'],
#  ['Mustafizur Rahman', 'New Zealand'],
#  ['Mustafizur Rahman', 'Pakistan'],
#  ['Mustafizur Rahman', 'South Africa'],
#  ['Mustafizur Rahman', 'Sri Lanka'],
#  ['Mustafizur Rahman', 'West Indies'],
#  ['Najibullah Zadran', 'Australia'],
#  ['Najibullah Zadran', 'Bangladesh'],
#  ['Najibullah Zadran', 'England'],
#  ['Najibullah Zadran', 'India'],
#  ['Najibullah Zadran', 'New Zealand'],
#  ['Najibullah Zadran', 'Pakistan'],
#  ['Najibullah Zadran', 'Sri Lanka'],
#  ['Najibullah Zadran', 'West Indies'],
#  ['Nathan Coulter-Nile', 'England'],
#  ['Nathan Coulter-Nile', 'India'],
#  ['Nathan Coulter-Nile', 'Pakistan'],
#  ['Nathan Coulter-Nile', 'South Africa'],
#  ['Nathan Coulter-Nile', 'West Indies'],
#  ['Nathan Lyon', 'England'],
#  ['Nathan Lyon', 'India'],
#  ['Nathan Lyon', 'Pakistan'],
#  ['Nathan Lyon', 'South Africa'],
#  ['Nathan Lyon', 'Sri Lanka'],
#  ['Nathan Lyon', 'West Indies'],
#  ['Nicholas Pooran ', 'England'],
#  ['Noor Ali Zadran', 'India'],
#  ['Noor Ali Zadran', 'Pakistan'],
#  ['Noor Ali Zadran', 'Sri Lanka'],
#  ['Noor Ali Zadran', 'West Indies'],
#  ['Nuwan Pradeep', 'Bangladesh'],
#  ['Nuwan Pradeep', 'England'],
#  ['Nuwan Pradeep', 'India'],
#  ['Nuwan Pradeep', 'New Zealand'],
#  ['Nuwan Pradeep', 'Pakistan'],
#  ['Nuwan Pradeep', 'South Africa'],
#  ['Nuwan Pradeep', 'West Indies'],
#  ['Oshane Thomas', 'Afghanistan'],
#  ['Oshane Thomas', 'Australia'],
#  ['Oshane Thomas', 'Bangladesh'],
#  ['Oshane Thomas', 'England'],
#  ['Oshane Thomas', 'India'],
#  ['Oshane Thomas', 'New Zealand'],
#  ['Oshane Thomas', 'Pakistan'],
#  ['Oshane Thomas', 'South Africa'],
#  ['Oshane Thomas', 'West Indies'],
#  ['Pat Cummins ', 'Bangladesh'],
#  ['Pat Cummins ', 'England'],
#  ['Pat Cummins ', 'India'],
#  ['Pat Cummins ', 'New Zealand'],
#  ['Pat Cummins ', 'Pakistan'],
#  ['Pat Cummins ', 'South Africa'],
#  ['Quinton de Kock ', 'Australia'],
#  ['Quinton de Kock ', 'Bangladesh'],
#  ['Quinton de Kock ', 'England'],
#  ['Quinton de Kock ', 'India'],
#  ['Quinton de Kock ', 'New Zealand'],
#  ['Quinton de Kock ', 'Pakistan'],
#  ['Quinton de Kock ', 'Sri Lanka'],
#  ['Quinton de Kock ', 'West Indies'],
#  ['Rahmat Shah', 'Bangladesh'],
#  ['Rahmat Shah', 'India'],
#  ['Rahmat Shah', 'Pakistan'],
#  ['Rahmat Shah', 'Sri Lanka'],
#  ['Rahmat Shah', 'West Indies'],
#  ['Rashid Khan ', 'Bangladesh'],
#  ['Rashid Khan ', 'India'],
#  ['Rashid Khan ', 'Pakistan'],
#  ['Rashid Khan ', 'Sri Lanka'],
#  ['Rashid Khan ', 'West Indies'],
#  ['Rassie van der Dussen', 'Pakistan'],
#  ['Rassie van der Dussen', 'Sri Lanka'],
#  ['Ravindra Jadeja', 'Afghanistan'],
#  ['Ravindra Jadeja', 'Australia'],
#  ['Ravindra Jadeja', 'Bangladesh'],
#  ['Ravindra Jadeja', 'England'],
#  ['Ravindra Jadeja', 'New Zealand'],
#  ['Ravindra Jadeja', 'Pakistan'],
#  ['Ravindra Jadeja', 'South Africa'],
#  ['Ravindra Jadeja', 'Sri Lanka'],
#  ['Ravindra Jadeja', 'West Indies'],
#  ['Rohit Sharma ', 'Afghanistan'],
#  ['Rohit Sharma ', 'Australia'],
#  ['Rohit Sharma ', 'Bangladesh'],
#  ['Rohit Sharma ', 'England'],
#  ['Rohit Sharma ', 'New Zealand'],
#  ['Rohit Sharma ', 'Pakistan'],
#  ['Rohit Sharma ', 'South Africa'],
#  ['Rohit Sharma ', 'Sri Lanka'],
#  ['Rohit Sharma ', 'West Indies'],
#  ['Ross Taylor', 'Afghanistan'],
#  ['Ross Taylor', 'Australia'],
#  ['Ross Taylor', 'Bangladesh'],
#  ['Ross Taylor', 'England'],
#  ['Ross Taylor', 'India'],
#  ['Ross Taylor', 'Pakistan'],
#  ['Ross Taylor', 'South Africa'],
#  ['Ross Taylor', 'Sri Lanka'],
#  ['Ross Taylor', 'West Indies'],
#  ['Rubel Hossain', 'Afghanistan'],
#  ['Rubel Hossain', 'Australia'],
#  ['Rubel Hossain', 'England'],
#  ['Rubel Hossain', 'India'],
#  ['Rubel Hossain', 'New Zealand'],
#  ['Rubel Hossain', 'Pakistan'],
#  ['Rubel Hossain', 'South Africa'],
#  ['Rubel Hossain', 'Sri Lanka'],
#  ['Rubel Hossain', 'West Indies'],
#  ['Sabbir Rahman', 'Afghanistan'],
#  ['Sabbir Rahman', 'Australia'],
#  ['Sabbir Rahman', 'England'],
#  ['Sabbir Rahman', 'India'],
#  ['Sabbir Rahman', 'New Zealand'],
#  ['Sabbir Rahman', 'Pakistan'],
#  ['Sabbir Rahman', 'South Africa'],
#  ['Sabbir Rahman', 'Sri Lanka'],
#  ['Sabbir Rahman', 'West Indies'],
#  ['Samiullah Shinwari', 'Australia'],
#  ['Samiullah Shinwari', 'Bangladesh'],
#  ['Samiullah Shinwari', 'England'],
#  ['Samiullah Shinwari', 'India'],
#  ['Samiullah Shinwari', 'New Zealand'],
#  ['Samiullah Shinwari', 'Pakistan'],
#  ['Samiullah Shinwari', 'Sri Lanka'],
#  ['Samiullah Shinwari', 'West Indies'],
#  ['Sarfaraz Ahmed ', 'Afghanistan'],
#  ['Sarfaraz Ahmed ', 'Australia'],
#  ['Sarfaraz Ahmed ', 'Bangladesh'],
#  ['Sarfaraz Ahmed ', 'England'],
#  ['Sarfaraz Ahmed ', 'India'],
#  ['Sarfaraz Ahmed ', 'New Zealand'],
#  ['Sarfaraz Ahmed ', 'South Africa'],
#  ['Sarfaraz Ahmed ', 'Sri Lanka'],
#  ['Sarfaraz Ahmed ', 'West Indies'],
#  ['Shadab Khan', 'Bangladesh'],
#  ['Shadab Khan', 'England'],
#  ['Shadab Khan', 'India'],
#  ['Shadab Khan', 'New Zealand'],
#  ['Shadab Khan', 'South Africa'],
#  ['Shadab Khan', 'Sri Lanka'],
#  ['Shadab Khan', 'West Indies'],
#  ['Shaheen Afridi', 'Afghanistan'],
#  ['Shaheen Afridi', 'Bangladesh'],
#  ['Shaheen Afridi', 'England'],
#  ['Shaheen Afridi', 'India'],
#  ['Shaheen Afridi', 'New Zealand'],
#  ['Shaheen Afridi', 'South Africa'],
#  ['Shai Hope', 'Afghanistan'],
#  ['Shai Hope', 'Bangladesh'],
#  ['Shai Hope', 'England'],
#  ['Shai Hope', 'India'],
#  ['Shai Hope', 'New Zealand'],
#  ['Shai Hope', 'Pakistan'],
#  ['Shai Hope', 'Sri Lanka'],
#  ['Shakib Al Hasan ', 'Afghanistan'],
#  ['Shakib Al Hasan ', 'Australia'],
#  ['Shakib Al Hasan ', 'England'],
#  ['Shakib Al Hasan ', 'India'],
#  ['Shakib Al Hasan ', 'New Zealand'],
#  ['Shakib Al Hasan ', 'Pakistan'],
#  ['Shakib Al Hasan ', 'South Africa'],
#  ['Shakib Al Hasan ', 'Sri Lanka'],
#  ['Shakib Al Hasan ', 'West Indies'],
#  ['Shannon Gabriel', 'Afghanistan'],
#  ['Shannon Gabriel', 'Australia'],
#  ['Shannon Gabriel', 'Bangladesh'],
#  ['Shannon Gabriel', 'England'],
#  ['Shannon Gabriel', 'New Zealand'],
#  ['Shannon Gabriel', 'Pakistan'],
#  ['Shannon Gabriel', 'South Africa'],
#  ['Shannon Gabriel', 'Sri Lanka'],
#  ['Shaun Marsh', 'Bangladesh'],
#  ['Shaun Marsh', 'England'],
#  ['Shaun Marsh', 'India'],
#  ['Shaun Marsh', 'New Zealand'],
#  ['Shaun Marsh', 'Pakistan'],
#  ['Shaun Marsh', 'South Africa'],
#  ['Shaun Marsh', 'Sri Lanka'],
#  ['Shaun Marsh', 'West Indies'],
#  ['Sheldon Cottrell', 'Bangladesh'],
#  ['Sheldon Cottrell', 'England'],
#  ['Sheldon Cottrell', 'New Zealand'],
#  ['Sheldon Cottrell', 'South Africa'],
#  ['Shikhar Dhawan', 'Afghanistan'],
#  ['Shikhar Dhawan', 'Australia'],
#  ['Shikhar Dhawan', 'Bangladesh'],
#  ['Shikhar Dhawan', 'England'],
#  ['Shikhar Dhawan', 'New Zealand'],
#  ['Shikhar Dhawan', 'Pakistan'],
#  ['Shikhar Dhawan', 'South Africa'],
#  ['Shikhar Dhawan', 'Sri Lanka'],
#  ['Shikhar Dhawan', 'West Indies'],
#  ['Shimron Hetmyer', 'Afghanistan'],
#  ['Shimron Hetmyer', 'Bangladesh'],
#  ['Shimron Hetmyer', 'England'],
#  ['Shimron Hetmyer', 'India'],
#  ['Shimron Hetmyer', 'New Zealand'],
#  ['Shoaib Malik', 'Afghanistan'],
#  ['Shoaib Malik', 'Australia'],
#  ['Shoaib Malik', 'Bangladesh'],
#  ['Shoaib Malik', 'England'],
#  ['Shoaib Malik', 'India'],
#  ['Shoaib Malik', 'New Zealand'],
#  ['Shoaib Malik', 'South Africa'],
#  ['Shoaib Malik', 'Sri Lanka'],
#  ['Shoaib Malik', 'West Indies'],
#  ['Soumya Sarkar', 'Afghanistan'],
#  ['Soumya Sarkar', 'Australia'],
#  ['Soumya Sarkar', 'England'],
#  ['Soumya Sarkar', 'India'],
#  ['Soumya Sarkar', 'New Zealand'],
#  ['Soumya Sarkar', 'Pakistan'],
#  ['Soumya Sarkar', 'South Africa'],
#  ['Soumya Sarkar', 'Sri Lanka'],
#  ['Soumya Sarkar', 'West Indies'],
#  ['Steve Smith', 'Afghanistan'],
#  ['Steve Smith', 'Bangladesh'],
#  ['Steve Smith', 'England'],
#  ['Steve Smith', 'India'],
#  ['Steve Smith', 'New Zealand'],
#  ['Steve Smith', 'Pakistan'],
#  ['Steve Smith', 'South Africa'],
#  ['Steve Smith', 'Sri Lanka'],
#  ['Steve Smith', 'West Indies'],
#  ['Tabraiz Shamsi', 'Australia'],
#  ['Tabraiz Shamsi', 'India'],
#  ['Tabraiz Shamsi', 'New Zealand'],
#  ['Tabraiz Shamsi', 'Pakistan'],
#  ['Tabraiz Shamsi', 'Sri Lanka'],
#  ['Tabraiz Shamsi', 'West Indies'],
#  ['Tamim Iqbal', 'Afghanistan'],
#  ['Tamim Iqbal', 'Australia'],
#  ['Tamim Iqbal', 'England'],
#  ['Tamim Iqbal', 'India'],
#  ['Tamim Iqbal', 'New Zealand'],
#  ['Tamim Iqbal', 'Pakistan'],
#  ['Tamim Iqbal', 'South Africa'],
#  ['Tamim Iqbal', 'Sri Lanka'],
#  ['Tamim Iqbal', 'West Indies'],
#  ['Thisara Perera', 'Afghanistan'],
#  ['Thisara Perera', 'Australia'],
#  ['Thisara Perera', 'Bangladesh'],
#  ['Thisara Perera', 'England'],
#  ['Thisara Perera', 'India'],
#  ['Thisara Perera', 'New Zealand'],
#  ['Thisara Perera', 'Pakistan'],
#  ['Thisara Perera', 'South Africa'],
#  ['Thisara Perera', 'West Indies'],
#  ['Tim Southee', 'Afghanistan'],
#  ['Tim Southee', 'Australia'],
#  ['Tim Southee', 'Bangladesh'],
#  ['Tim Southee', 'England'],
#  ['Tim Southee', 'India'],
#  ['Tim Southee', 'Pakistan'],
#  ['Tim Southee', 'South Africa'],
#  ['Tim Southee', 'Sri Lanka'],
#  ['Tim Southee', 'West Indies'],
#  ['Tom Curran', 'Australia'],
#  ['Tom Curran', 'New Zealand'],
#  ...]

# %%
#g2
e=[]
e2=[]
for i in range(0,len(g1),1):
     g1[i].append(g2[i])
for i in g1:
    if(i[0]=="Aaron Finch "):
        e.append(i[1])
        e2.append(i[3])
e
# Out:
# ['Afghanistan',
#  'Bangladesh',
#  'England',
#  'India',
#  'New Zealand',
#  'Pakistan',
#  'South Africa',
#  'Sri Lanka',
#  'West Indies']

# %%
df2
# Out:
#                                                 Ground  Mat  Won  Tied  Runs  \
# 0                        Eden Gardens, Kolkata - India    4    4     0  2161
# 1                      Feroz Shah Kotla, Delhi - India    4    4     0  1789
# 2                 Melbourne Cricket Ground - Australia   15   15     0  7656
# 3    Saurashtra Cricket Association Stadium, Rajkot...    2    2     0  1163
# 4                            Adelaide Oval - Australia   10   10     0  4863
# ..                                                 ...  ...  ...   ...   ...
# 101  Greenfield International Stadium, Thiruvananth...    1    1     0   209
# 102  Sylhet International Cricket Stadium - Bangladesh    1    1     0   400
# 103  Rajiv Gandhi International Cricket Stadium, De...    5    4     0  1864
# 104       Wanderers Cricket Ground, Windhoek - Namibia    1    1     0   307
# 105                    Affies Park, Windhoek - Namibia    1    1     0   329
#
#      Wkts  Balls    Ave   RPO
# 0      72   2297  30.01  5.64
# 1      75   2331  23.85  4.60
# 2     217   8482  35.28  5.41
# 3      26   1200  44.73  5.81
# 4     157   5645  30.97  5.16
# ..    ...    ...    ...   ...
# 101    11    280  19.00  4.47
# 102    11    531  36.36  4.51
# 103    67   2524  27.82  4.43
# 104    17    474  18.05  3.88
# 105    15    460  21.93  4.29
#
# [106 rows x 9 columns]

# %%
    index = np.arange(len(df2['Ground']))
    plt.figure(figsize=(30, 15))
    plt.bar(index, df2['Runs'],color='green',align='edge',width=0.4)
    plt.xlabel('Grounds', fontsize=10)
    plt.ylabel('Runs', fontsize=10)
    plt.xticks(index, df2['Ground'], fontsize=14,rotation=90)
    plt.title('Best batting pitch')
    plt.show()

# %%
df2['Ground']
# Out:
# 0                          Eden Gardens, Kolkata - India
# 1                        Feroz Shah Kotla, Delhi - India
# 2                   Melbourne Cricket Ground - Australia
# 3      Saurashtra Cricket Association Stadium, Rajkot...
# 4                              Adelaide Oval - Australia
#                              ...
# 101    Greenfield International Stadium, Thiruvananth...
# 102    Sylhet International Cricket Stadium - Bangladesh
# 103    Rajiv Gandhi International Cricket Stadium, De...
# 104         Wanderers Cricket Ground, Windhoek - Namibia
# 105                      Affies Park, Windhoek - Namibia
# Name: Ground, Length: 106, dtype: object

# %%
    index = np.arange(len(df2['Ground'][0:25]))
    plt.figure(figsize=(30, 15))
    plt.bar(index, df2['Wkts'][0:25],color='red',align='center', width=0.4)
    plt.xlabel('Grounds', fontsize=30)
    plt.ylabel('Wkts', fontsize=30)
    plt.xticks(index, df2['Ground'][0:25], fontsize=20,rotation=90)
    plt.title('Best Bowling Pitch',fontsize=30)
    plt.show()

# %%
#gbat.dropna()
#gbowl.dropna()

e3=[float(i) for i in e2]
e3
# Out:
# [4.0,
#  19.0,
#  46.12,
#  40.52,
#  13.0,
#  53.888888888888886,
#  35.36842105263158,
#  23.625,
#  18.555555555555557]

# %%
    index = np.arange(len(e))
    plt.figure(figsize=(30, 7))
    plt.bar(e, e3,align='center', color='green',width=0.3)
    plt.xlabel('Countries', fontsize=30)
    plt.ylabel('Average Runs scored', fontsize=30)
    plt.xticks(index,e, fontsize=20,rotation=90)
    plt.title('Aaron Finch Batting performance ',fontsize=30)
    plt.show()

# %%
e12=[]
e21=[]
k1=df1.groupby(['Bowler','Opposition'])
k2=[]
k3=[]
for i,j in k1:
    k2.append(list(i))
    k3.append(str(j.Wkts.mean()))

for i in range(0,len(k2),1):
     k2[i].append(k3[i])
for i in k2:
    if(i[0]=='Bhuvneshwar Kumar'):
        e12.append(i[1])
        e21.append(float(i[2]))
index = np.arange(len(e12))
plt.figure(figsize=(30, 7))
plt.bar(index, e21,align='center', color='blue',width=0.3)
plt.xlabel('Countries', fontsize=30)
plt.ylabel('Average Wickets taken', fontsize=30)
plt.xticks(index,e12, fontsize=20,rotation=90)
plt.title('Bhuvneshwar Kumar\'s Bowling performance ',fontsize=30)
plt.show()

# %%
g3=df1.groupby(['Bowler','Opposition'])
g4=[]
g5=[]
g6=[]
g7=[]
for i,j in g3:
    g4.append(list(i))
    g5.append(str(j.Wkts.mean()))
    g6.append(str(j.Econ.mean()))
    g7.append(str(j.Ave.mean()))

wk=[]
econ=[]
ave=[]
c=[]
for i in range(0,len(g4),1):
        g4[i].append(g5[i])
        g4[i].append(g6[i])
        g4[i].append(g7[i])
for i in g4:
    if(i[0]=='Adam Zampa'):
        
        wk.append(float(i[2]))
        econ.append(float(i[3]))
        ave.append(float(i[4]))
        c.append(i[1])
g10=[]
for i in g4:
    if(i[0]=='Adam Zampa'):
        g10.append([i[1],i[2],i[3],i[4]])
g10
# Out:
# [['Bangladesh', '2.0', '3.25', '6.5'],
#  ['England', '0.4', '6.029999999999999', '20.2'],
#  ['India', '1.6666666666666667', '5.863333333333333', '34.406666666666666'],
#  ['New Zealand', '1.25', '5.6625', '26.625'],
#  ['Pakistan', '1.5714285714285714', '5.6085714285714285', '37.72571428571428'],
#  ['South Africa',
#   '0.7777777777777778',
#   '6.225555555555555',
#   '21.59222222222222'],
#  ['Sri Lanka', '1.8', '4.752000000000001', '15.632'],
#  ['West Indies', '2.0', '5.489999999999999', '28.44333333333333']]

# %%
index=np.arange(len(g10))
bars = np.add(wk, econ).tolist()
plt.bar(x=index,height=wk,color='red',width=0.35)
plt.bar(x=index,height=econ,color='orange',width=0.35,bottom=wk)
plt.bar(x=index,height=ave,color='blue',bottom=bars,width=0.35)

plt.xlabel('Countries', fontsize=30)
plt.ylabel('Bowling stats', fontsize=30)
plt.xticks(index,c, fontsize=20,rotation=90)
plt.title('Adam Zampa performance ',fontsize=30)

import matplotlib.patches as mpa
red=mpa.Patch(color='red',label='Wickets')
orange=mpa.Patch(color='orange',label='Economy')
blue=mpa.Patch(color='blue',label='Average')
plt.legend(handles=[red,orange,blue],loc='upper left')
plt.show()

# %%
plt.bar(x=index,height=wk,color='red',width=0.35)
plt.xlabel('Countries', fontsize=20)
plt.ylabel('Wickets against each team', fontsize=10)
plt.xticks(index,c, fontsize=15,rotation=90)
plt.title('Adam Zampa wickets ',fontsize=30)
plt.show()

# %%
#Regression Problem 
q=df.groupby(['Batsman','Runs','BF'])
runsscored=[]
ballsfaced=[]
player=[]

for i,j in q:
    player.append(list(i))
for i in player:
    if(i[0]=='Virat Kohli '):
        runsscored.append(float(i[1]))
        ballsfaced.append(float(i[2]))
len(runsscored)==len(ballsfaced)

plt.scatter(ballsfaced,runsscored,color='red')
plt.xlabel("Balls Faced",fontsize=20)
plt.ylabel("Runs scored",fontsize=20)
plt.title("Virat Kohli's runs prediction")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
bf2=[[x] for x in ballsfaced]
X_train,X_test,Y_train,Y_test=train_test_split(bf2,runsscored,test_size=0.3,random_state=3)
reg=LinearRegression()
reg.fit(X_train,Y_train)
y_predict=reg.predict(X_test)

plt.scatter(X_train,Y_train,color='green')
plt.plot(X_train,reg.predict(X_train))
plt.xlabel("Balls Faced",fontsize=20)
plt.ylabel("Runs scored",fontsize=20)
plt.title("Virat Kohli's runs prediction")
plt.show()

# %%
reg.predict([[25.0],[140.0]])
z=reg.score(X_test,Y_test)
# Out:
# 0.9162840262181082

# %%
#Hypothesis1 
#Indian fast bowler : Bhuvneshwar Kumar 
#Indian slow bowler : Yuzvendra Chahal
abc=df1.groupby(['Bowler','Opposition'])
bowler=[]
econstr=[]
fastbowlers=[]
slowbowlers=[]

econvalbhuv=[]
econvalchahal=[]
for i,j in abc:
    bowler.append((list(i)))
    econstr.append(str(j.Econ.mean()))
for i in range(0,len(bowler),1):
    if(bowler[i][0]=='Bhuvneshwar Kumar'):
        econvalbhuv.append(float(econstr[i]))
    if(bowler[i][0]=='Yuzvendra Chahal'):
        econvalchahal.append(float(econstr[i]))

fastbowlers.append(econvalbhuv)
slowbowlers.append(econvalchahal)

#England fast bowler : Ben Stokes
#England slow bowler : Adil Rashid
econvalben=[]
econvalrash=[]
for i in range(0,len(bowler),1):
    if(bowler[i][0]=='Ben Stokes'):
        econvalben.append(float(econstr[i]))
    elif(bowler[i][0]=='Adil Rashid'):
        econvalrash.append(float(econstr[i]))
fastbowlers.append(econvalben)
slowbowlers.append(econvalrash)

#Australian fast bowler : Mitchell Starc
#Australian slow bowler : Adam Zampa
econvalsta=[]
econvalz=[]
for i in range(0,len(bowler),1):
    if(bowler[i][0]=='Mitchell Starc'):
        econvalsta.append(float(econstr[i]))
    elif(bowler[i][0]=='Adam Zampa'):
        econvalz.append(float(econstr[i]))
fastbowlers.append(econvalsta)
slowbowlers.append(econvalz)

# %%
from scipy.stats import ttest_ind
ttest_ind(fastbowlers[0][0:9],slowbowlers[0][0:9],equal_var=True)
# Out:
# Ttest_indResult(statistic=-0.454193450435246, pvalue=0.6561925591340334)

# %%
ttest_ind(fastbowlers[1],slowbowlers[1],equal_var=True)
# Out:
# Ttest_indResult(statistic=-0.13062947381583073, pvalue=0.897926908790694)

# %%
ttest_ind(fastbowlers[2][0:9],slowbowlers[2][0:9],equal_var=True)
# Out:
# Ttest_indResult(statistic=-1.6427836074902311, pvalue=0.12122012739568677)

# %%
s1=[]
for i in fastbowlers:
    s1=i+i

s1=fastbowlers[0]+fastbowlers[1]+fastbowlers[2]
s2=slowbowlers[0]+slowbowlers[1]+slowbowlers[2]
ttest_ind(s1,s2,equal_var=True)
print(s2)
# Out:
# [5.625, 3.935, 4.499999999999999, 5.74125, 4.98, 5.501666666666666, 4.2, 5.333333333333333, 5.819999999999999, 5.013333333333333, 6.225, 5.651818181818182, 5.751666666666666, 5.727777777777778, 4.6930000000000005, 4.2907692307692304, 3.25, 6.029999999999999, 5.863333333333333, 5.6625, 5.6085714285714285, 6.225555555555555, 4.752000000000001, 5.489999999999999]

# %%
import statistics as st

d={
     'FastBowlers':pd.Series(s1[0:24]),
     'SlowBowlers':pd.Series(s2)
}
dd=pd.DataFrame(d)
dd.describe()
# Out:
#        FastBowlers  SlowBowlers
# count    24.000000    24.000000
# mean      4.959422     5.244649
# std       0.897261     0.770731
# min       3.120000     3.250000
# 25%       4.195278     4.737250
# 50%       5.032500     5.555119
# 75%       5.574353     5.743854
# max       6.537500     6.225556

# %%
from scipy.stats import variation
p1= variation(s1[0:24])
p2=variation(s2)
p1,p2
# Out:
# (0.17711126698213692, 0.14386150306639342)

# %%
from scipy.stats import skew
p1= skew(s1)
p2=skew(s2)
p1,p2
# Out:
# (-0.034135060309169254, -0.9198336271027852)

# %%
fp=pd.read_csv("Batno.csv")

# %%
fp.drop(fp.columns[0],axis=1)
# Out:
#           Runs        BF        SR        4s        6s
# 0    -0.530510 -0.337359 -0.344079 -1.020189 -0.605258
# 1    -0.844923 -0.656925 -1.012365 -1.020189 -0.605258
# 2    -0.687717 -0.878163  2.057192 -0.738295 -0.605258
# 3    -0.661515 -0.484851 -0.500626 -0.456400 -0.605258
# 4     0.045914 -0.017793  0.435150  0.389283 -0.605258
# ...        ...       ...       ...       ...       ...
# 9359 -0.260851 -0.280187 -0.324964 -0.230961       NaN
# 9360 -0.260851 -0.280187 -0.324964 -0.230961       NaN
# 9361  4.848764  5.444819  1.936215  4.896366       NaN
# 9362 -0.260851 -0.125457 -0.324964 -0.230961       NaN
# 9363 -0.260851 -0.125457 -0.324964 -0.230961       NaN
#
# [9364 rows x 5 columns]

# %%
k1=df.groupby(['Batsman','Opposition'])
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
for i,j in k1:
    k2.append(list(i))
    k3.append(str(j.Runs.mean()))
    k4.append(str(j.SR.mean()))
    #k5.append(str(j.k1["4s"].mean()))
    #k6.append(str(j.k1["6s"].mean()))

bat=fp['Runs']
sr=fp['BF']
runs1=[]
bfs=[]
for i in range(0,len(k2),1):
    k2[i].append(float(bat[i]))
    k2[i].append(float(sr[i]))
for i in k2:
    if(i[0]=='David Warner'):
        runs1.append(float(i[2]))
        bfs.append(float(i[3]))

# %%
runs1
# Out:
# [-0.5100495338350031,
#  -0.5100495338350031,
#  -0.5100495338350031,
#  -0.5100495338350031,
#  0.2581475191654709,
#  -0.5100495338350031,
#  -0.5100495338350031,
#  -0.5100495338350031,
#  0.5142132034989623]

# %%
bfs
# Out:
# [-0.525542274904567,
#  -0.525542274904567,
#  -0.525542274904567,
#  -0.525542274904567,
#  -0.2584278128662953,
#  -0.525542274904567,
#  -0.525542274904567,
#  -0.4365041208918097,
#  0.4538774192357624]

# %%
plt.plot(df['BF'],df['Runs'],color='red')
plt.xlabel("Balls Faced",fontsize=20)
plt.ylabel("Runs scored",fontsize=20)
plt.title("Batsmen normal plot")
plt.show()

# %%
from sklearn import preprocessing
scaler = preprocessing.Normalizer()
scaled_df = scaler.fit_transform([df['Runs']])
scale=scaler.fit_transform([df['BF']])

s1=scaler.fit_transform([df['SR']])
s2=scaler.fit_transform([df['4s']])
s3=scaler.fit_transform([df['6s']])
plt.plot(scale[0],scaled_df[0])
plt.show()
a=sns.distplot(scaled_df[0])
b=sns.distplot(scale[0])
c=sns.distplot(s1[0])
d=sns.distplot(s2[0])
e=sns.distplot(s3[0])

# %%
a1=sns.distplot([df['Runs']])
b1=sns.distplot([df['BF']])
c1=sns.distplot([df['SR']])
d1=sns.distplot([df['4s']])
e1=sns.distplot([df['6s']])

# %%
import statistics as st
meanofruns=st.mean(scaled_df[0])

# %%
meanofruns
# Out:
# 0.006195284429965756

# %%
st.variance(scaled_df[0])
# Out:
# 6.841772653948507e-05

# %%
a=df['Runs'].transform(lambda x: (x - x.mean())/x.std())
b=df['BF'].transform(lambda x: (x - x.mean())/x.std())
c=df['SR'].transform(lambda x: (x - x.mean())/x.std())
d=df['4s'].transform(lambda x: (x - x.mean())/x.std())
e=df['6s'].transform(lambda x: (x - x.mean())/x.std())

# %%
a
# Out:
# 0       -0.225787
# 1       -0.618190
# 2       -0.421989
# 3       -0.389288
# 4        0.493619
#            ...
# 11144   -0.748992
# 11145   -0.748992
# 11146   -0.160386
# 11147   -0.748992
# 11148   -0.748992
# Name: Runs, Length: 9364, dtype: float64

# %%
a.mean()
# Out:
# 1.2837991147630493e-16

# %%
sns.distplot(a)

# %%
sns.distplot([df['Runs']])

# %%
# Out:
# (0       -0.225787
#  1       -0.618190
#  2       -0.421989
#  3       -0.389288
#  4        0.493619
#             ...
#  11144   -0.748992
#  11145   -0.748992
#  11146   -0.160386
#  11147   -0.748992
#  11148   -0.748992
#  Name: Runs, Length: 9364, dtype: float64, 0        0.048192
#  1       -0.364042
#  2       -0.649435
#  3       -0.142070
#  4        0.460426
#             ...
#  11144   -0.839697
#  11145   -0.839697
#  11146    0.333585
#  11147   -0.807986
#  11148   -0.807986
#  Name: BF, Length: 9364, dtype: float64)

# %%
    index = np.arange(len(df2['Ground'][25:50]))
    plt.figure(figsize=(30, 15))
    plt.bar(index, df2['Wkts'][25:50],color='red',align='center', width=0.4)
    plt.xlabel('Grounds', fontsize=30)
    plt.ylabel('Wkts', fontsize=30)
    plt.xticks(index, df2['Ground'][25:50], fontsize=20,rotation=90)
    plt.title('Best Bowling Pitch',fontsize=30)
    plt.show()

# %%
    index = np.arange(len(df2['Ground'][51:75]))
    plt.figure(figsize=(30, 15))
    plt.bar(index, df2['Wkts'][51:75],color='red',align='center', width=0.4)
    plt.xlabel('Grounds', fontsize=30)
    plt.ylabel('Wkts', fontsize=30)
    plt.xticks(index, df2['Ground'][51:75], fontsize=20,rotation=90)
    plt.title('Best Bowling Pitch',fontsize=30)
    plt.show()

# %%
    index = np.arange(len(df2['Ground'][76:107]))
    plt.figure(figsize=(30, 15))
    plt.bar(index, df2['Wkts'][76:107],color='red',align='center', width=0.4)
    plt.xlabel('Grounds', fontsize=30)
    plt.ylabel('Wkts', fontsize=30)
    plt.xticks(index, df2['Ground'][76:107], fontsize=20,rotation=90)
    plt.title('Best Bowling Pitch',fontsize=30)
    plt.show()
